# %%
import pandas as pd
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)

# %%
df=pd.read_csv(r'C:\Users\RaghulRamesh\Downloads\18 - Day - 18 - Linear Regression Practise Python\18 - Day - 18 - Linear Regression Practise Python\company.csv')

# %%
df.head()
# Out:
#    Company   Age  Salary     Place
# 0      TCS  20.0     NaN   Chennai
# 1  Infosys  30.0     NaN    Mumbai
# 2      TCS  35.0  2300.0  Calcutta
# 3  Infosys  40.0  3000.0     Delhi
# 4      TCS  23.0  4000.0    Mumbai

# %%
df.tail()
# Out:
#      Company   Age  Salary     Place
# 143      TCS  33.0  9024.0  Calcutta
# 144  Infosys  22.0  8787.0  Calcutta
# 145  Infosys  44.0  4034.0     Delhi
# 146      TCS  33.0  5034.0    Mumbai
# 147  Infosys  22.0  8202.0    Cochin

# %%
df
# Out:
#                        Company   Age  Salary       Place
# 0                          TCS  20.0     NaN     Chennai
# 1                      Infosys  30.0     NaN      Mumbai
# 2                          TCS  35.0  2300.0    Calcutta
# 3                      Infosys  40.0  3000.0       Delhi
# 4                          TCS  23.0  4000.0      Mumbai
# 5                      Infosys   NaN  5000.0    Calcutta
# 6                          TCS   NaN  6000.0     Chennai
# 7                      Infosys  23.0  7000.0      Mumbai
# 8                          TCS  34.0  8000.0    Calcutta
# 9                          CTS  45.0  9000.0       Delhi
# 10                         CTS  23.0     NaN      Mumbai
# 11                         CTS  34.0  1089.0    Calcutta
# 12                         CTS  45.0     NaN     Chennai
# 13                         CTS  18.0  1234.0      Mumbai
# 14                     Infosys  40.0  3000.0    Calcutta
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place'], dtype='object')

# %%
df['Company'].unique()
# Out:
# array(['TCS', 'Infosys', 'CTS', nan, 'Tata Consultancy Services',
#        'Congnizant', 'Infosys Pvt Lmt'], dtype=object)

# %%
df['Company'].value_counts()
# Out:
# TCS                          53
# Infosys                      45
# CTS                          36
# Tata Consultancy Services     2
# Congnizant                    2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64

# %%
df['Company'].replace({'Tata Consultancy Services':'TCS',
                      'Congnizant':'CTS',
                      'Infosys Pvt Lmt':'Infosys'},inplace=True)

# %%
df['Company']
# Out:
# 0          TCS
# 1      Infosys
# 2          TCS
# 3      Infosys
# 4          TCS
# 5      Infosys
# 6          TCS
# 7      Infosys
# 8          TCS
# 9          CTS
# 10         CTS
# 11         CTS
# 12         CTS
# 13         CTS
# 14     Infosys
# 15         TCS
# 16     Infosys
# 17         TCS
# 18         TCS
# 19     Infosys
# 20         TCS
# 21     Infosys
# 22         TCS
# 23     Infosys
# 24         TCS
# 25     Infosys
# 26         TCS
# 27         CTS
# 28         CTS
# 29         CTS
# 30         CTS
# 31         CTS
# 32     Infosys
# 33         TCS
# 34     Infosys
# 35         TCS
# 36         TCS
# 37         NaN
# 38         TCS
# 39     Infosys
# 40         TCS
# 41     Infosys
# 42         TCS
# 43     Infosys
# 44         TCS
# 45         CTS
# 46         CTS
# 47         CTS
# 48         CTS
# 49         CTS
# 50     Infosys
# 51         NaN
# 52     Infosys
# 53         TCS
# 54         TCS
# 55     Infosys
# 56         TCS
# 57     Infosys
# ...

# %%
df['Company'].isnull().sum()
# Out:
# 8

# %%
#df.dropna(subset=['Company'])
df['Company'].mode()[0]
# Out:
# 'TCS'

# %%
df['Company'].fillna(df['Company'].mode()[0],inplace=True)

# %%
df['Company'].isnull().sum()
# Out:
# 0

# %%
df['Company'].value_counts()
# Out:
# TCS        63
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %%
df['Age'].min()
# Out:
# 0.0

# %%
df['Age'].max()
# Out:
# 54.0

# %%
df['Age'].mean()
# Out:
# 30.484615384615385

# %%
df['Age'].isnull().sum()
# Out:
# 18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  148 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 4.8+ KB

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  148 non-null    object
#  1   Age      148 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 4.8+ KB

# %%
df['Salary'].isnull().sum()
# Out:
# 24

# %%
df['Salary'].min()
# Out:
# 1089.0

# %%
df['Salary'].max()
# Out:
# 9876.0

# %%
df['Salary'].mean()
# Out:
# 5312.467741935484

# %%
df['Salary']=df['Salary'].fillna(df['Salary'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  148 non-null    object
#  1   Age      148 non-null    float64
#  2   Salary   148 non-null    float64
#  3   Place    134 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 4.8+ KB

# %%
from matplotlib import pyplot as plt

# %%
plt.bar(df['Company'].unique(),df['Company'].value_counts(),color='g',width=0.3)
plt.show()

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place'], dtype='object')

# %%
df=df.drop(columns=['Place'])

# %%
df.head()
# Out:
#    Company   Age       Salary
# 0      TCS  20.0  5312.467742
# 1  Infosys  30.0  5312.467742
# 2      TCS  35.0  2300.000000
# 3  Infosys  40.0  3000.000000
# 4      TCS  23.0  4000.000000

# %%
def get_category(sal):
    if sal >= 5000:
        return "high paid"
    else:
        return "less paid"

# %%
df['Category']= df['Salary'].apply(get_category)

# %%
df.head()
# Out:
#    Company   Age       Salary   Category
# 0      TCS  20.0  5312.467742  high paid
# 1  Infosys  30.0  5312.467742  high paid
# 2      TCS  35.0  2300.000000  less paid
# 3  Infosys  40.0  3000.000000  less paid
# 4      TCS  23.0  4000.000000  less paid

# %%
df.iloc[ 100: 111, 0:3 ]
# Out:
#      Company   Age       Salary
# 100      CTS  22.0  5312.467742
# 101      CTS   0.0  2034.000000
# 102      CTS  44.0  5312.467742
# 103      CTS  22.0  2934.000000
# 104  Infosys  44.0  4034.000000
# 105      TCS  33.0  5034.000000
# 106  Infosys  22.0  8202.000000
# 107      TCS   0.0  9024.000000
# 108      TCS  33.0  5312.467742
# 109      TCS  33.0  5312.467742
# 110      TCS  33.0  2300.000000

# %%
df.iloc[100]
# Out:
# Company             CTS
# Age                22.0
# Salary      5312.467742
# Category      high paid
# Name: 100, dtype: object

# %%
df.head()
# Out:
#    Company   Age       Salary   Category
# 0      TCS  20.0  5312.467742  high paid
# 1  Infosys  30.0  5312.467742  high paid
# 2      TCS  35.0  2300.000000  less paid
# 3  Infosys  40.0  3000.000000  less paid
# 4      TCS  23.0  4000.000000  less paid

# %%
df.loc[100:105,['Company','Salary']]
# Out:
#      Company       Salary
# 100      CTS  5312.467742
# 101      CTS  2034.000000
# 102      CTS  5312.467742
# 103      CTS  2934.000000
# 104  Infosys  4034.000000
# 105      TCS  5034.000000

# %%
df[(df['Company']=='TCS') & (df['Salary']>9000)]
# Out:
#     Company   Age  Salary   Category
# 35      TCS  35.0  9024.0  high paid
# 71      TCS  34.0  9024.0  high paid
# 107     TCS   0.0  9024.0  high paid
# 143     TCS  33.0  9024.0  high paid

# %%
df['Age'].replace({0.0 : 21}, inplace=True)

# %%
df.iloc[107]
# Out:
# Company           TCS
# Age              21.0
# Salary         9024.0
# Category    high paid
# Name: 107, dtype: object

# %%
df[df['Company']!='TCS']
# Out:
#      Company        Age       Salary   Category
# 1    Infosys  30.000000  5312.467742  high paid
# 3    Infosys  40.000000  3000.000000  less paid
# 5    Infosys  30.484615  5000.000000  high paid
# 7    Infosys  23.000000  7000.000000  high paid
# 9        CTS  45.000000  9000.000000  high paid
# 10       CTS  23.000000  5312.467742  high paid
# 11       CTS  34.000000  1089.000000  less paid
# 12       CTS  45.000000  5312.467742  high paid
# 13       CTS  18.000000  1234.000000  less paid
# 14   Infosys  40.000000  3000.000000  less paid
# 16   Infosys  23.000000  3030.000000  less paid
# 19   Infosys  32.000000  5312.467742  high paid
# 21   Infosys  50.000000  3184.000000  less paid
# 23   Infosys  30.484615  5835.000000  high paid
# 25   Infosys  23.000000  8943.000000  high paid
# 27       CTS  45.000000  9284.000000  high paid
# 28       CTS  23.000000  9876.000000  high paid
# 29       CTS  35.000000  2034.000000  less paid
# 30       CTS  46.000000  7654.000000  high paid
# ...

# %%
df[df['Age']<21]
# Out:
#     Company   Age       Salary   Category
# 0       TCS  20.0  5312.467742  high paid
# 13      CTS  18.0  1234.000000  less paid
# 31      CTS  20.0  2934.000000  less paid
# 49      CTS  19.0  1234.000000  less paid
# 85      CTS  17.0  1234.000000  less paid
# 126     TCS  20.0  5009.000000  high paid

# %%
df.sort_values(by=['Salary','Age'],ascending=False)
# Out:
#      Company        Age       Salary   Category
# 117      CTS  44.000000  9876.000000  high paid
# 28       CTS  23.000000  9876.000000  high paid
# 27       CTS  45.000000  9284.000000  high paid
# 99       CTS  44.000000  9284.000000  high paid
# 63       CTS  41.000000  9284.000000  high paid
# 135      CTS  40.000000  9284.000000  high paid
# 35       TCS  35.000000  9024.000000  high paid
# 71       TCS  34.000000  9024.000000  high paid
# 143      TCS  33.000000  9024.000000  high paid
# 107      TCS  21.000000  9024.000000  high paid
# 45       CTS  46.000000  9000.000000  high paid
# 9        CTS  45.000000  9000.000000  high paid
# 81       CTS  43.000000  9000.000000  high paid
# 61       TCS  25.000000  8943.000000  high paid
# 25   Infosys  23.000000  8943.000000  high paid
# 97   Infosys  22.000000  8943.000000  high paid
# 133      TCS  22.000000  8943.000000  high paid
# 116      TCS  33.000000  8787.000000  high paid
# 115  Infosys  22.000000  8787.000000  high paid
# ...

# %%
df.groupby('Company')['Salary'].max()
# Out:
# Company
# CTS        9876.0
# Infosys    8943.0
# TCS        9024.0
# Name: Salary, dtype: float64

# %%
df.groupby('Company')['Salary'].min()
# Out:
# Company
# CTS        1089.0
# Infosys    3000.0
# TCS        2300.0
# Name: Salary, dtype: float64

# %%
df.groupby('Company')['Salary'].mean()
# Out:
# Company
# CTS        4794.109083
# Infosys    5329.741935
# TCS        5612.241423
# Name: Salary, dtype: float64

# %%
df.groupby('Company')['Salary'].agg(['min','max','sum'])
# Out:
#             min     max            sum
# Company
# CTS      1089.0  9876.0  182176.145161
# Infosys  3000.0  8943.0  250497.870968
# TCS      2300.0  9024.0  353571.209677

# %%
df.groupby(['Company','Category'])['Salary'].agg(['min','max','sum'])
# Out:
#                            min     max            sum
# Company Category
# CTS     high paid  5312.467742  9876.0  149979.145161
#         less paid  1089.000000  3033.0   32197.000000
# Infosys high paid  5000.000000  8943.0  184033.870968
#         less paid  3000.000000  4034.0   66464.000000
# TCS     high paid  5000.000000  9024.0  283772.209677
#         less paid  2300.000000  4824.0   69799.000000

# %%
df
# Out:
#      Company        Age       Salary   Category
# 0        TCS  20.000000  5312.467742  high paid
# 1    Infosys  30.000000  5312.467742  high paid
# 2        TCS  35.000000  2300.000000  less paid
# 3    Infosys  40.000000  3000.000000  less paid
# 4        TCS  23.000000  4000.000000  less paid
# 5    Infosys  30.484615  5000.000000  high paid
# 6        TCS  30.484615  6000.000000  high paid
# 7    Infosys  23.000000  7000.000000  high paid
# 8        TCS  34.000000  8000.000000  high paid
# 9        CTS  45.000000  9000.000000  high paid
# 10       CTS  23.000000  5312.467742  high paid
# 11       CTS  34.000000  1089.000000  less paid
# 12       CTS  45.000000  5312.467742  high paid
# 13       CTS  18.000000  1234.000000  less paid
# 14   Infosys  40.000000  3000.000000  less paid
# 15       TCS  23.000000  3000.000000  less paid
# 16   Infosys  23.000000  3030.000000  less paid
# 17       TCS  34.000000  5000.000000  high paid
# 18       TCS  22.000000  5312.467742  high paid
# ...

# %%
df.to_csv(r'C:\Users\RaghulRamesh\OneDrive\Desktop\Mobily_Infotech\company_data.csv', index=False)

# %%
df.count()
# Out:
# Company     148
# Age         148
# Salary      148
# Category    148
# dtype: int64

# %%
df[df.duplicated()].count()
# Out:
# Company     33
# Age         33
# Salary      33
# Category    33
# dtype: int64

# %%
df[(df['Company']=='Infosys') & (df['Age'] == 40 ) & (df['Salary']==3000)]
# Out:
#     Company   Age  Salary   Category
# 3   Infosys  40.0  3000.0  less paid
# 14  Infosys  40.0  3000.0  less paid

# %%
df=df.drop_duplicates()

# %%
df.count()
# Out:
# Company     115
# Age         115
# Salary      115
# Category    115
# dtype: int64
